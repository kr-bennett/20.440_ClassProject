# %%
# PSET4 - Kimberly Bennett
# This code generates a PRELIMINARY rendition of a figure related to our
# project. A heatmap of 500 genes' expression counts over several cell
# samples will be created. The top 500 genes out of 28336 genes are displayed
# from 3186 different cell samples. Future work will include a breakdown
# of the types of cells samples in order to distinguish significance.

# Import necessary toolboxes:
import pandas as pd
import seaborn
import matplotlib.pyplot as plt

# %%
# Add a tool to read the given MTX Matrix Market file:
from scipy.io import mmread

# Import a file with Normalized Counts of gene expression (unit = cpm)
Normalized_Counts = 
    (mmread('E-GEOD-98816.aggregated_filtered_normalised_counts.mtx'))
#file taken from the NCBI database and upload to the project github

NC = Normalized_Counts.todense() #process the MTX file

df = pd.DataFrame(NC, range(1, NC.shape[0] + 1), range(1, NC.shape[1] + 1))
# convert the MTX file into a pandas df

new_df = df.iloc[:500,:3186] #take the first 500 genes of the df
print(new_df) #print the df to view values
# Out:
#            1           2           3            4           5          6     \
# 1      0.000000  628.746300    2.293448     2.796882   42.022984    0.00000
# 2      0.000000    0.000000    0.000000     0.000000    0.000000    0.00000
# 3     97.833466   71.252310  240.659000  1110.942600  191.013900   69.89071
# 4      0.000000    0.000000    0.000000     0.000000    0.000000    0.00000
# 5      0.000000    0.000000    0.000000     0.000000    0.000000    0.00000
# ..          ...         ...         ...          ...         ...        ...
# 496    0.000000    0.000000    0.000000     0.000000    2.334610    0.00000
# 497  316.729640   19.761074   30.270510   132.499400    3.038612  187.29074
# 498  213.616410  457.435700    2.293448   472.673100  670.033140  833.93646
# 499   20.540040  419.164180  353.190950     0.000000  308.168550  301.76675
# 500    0.000000    0.000000    0.000000     0.000000  130.738170    0.00000
#
#            7            8           9          10    ...        3177  \
# 1    258.323760     0.000000  695.095400   0.000000  ...  170.844970
# 2      0.000000     0.000000    0.000000   0.000000  ...    0.000000
# 3    223.108060   121.578470  140.989790   2.041520  ...   66.876434
# 4      0.000000     0.000000    0.000000   0.000000  ...    0.000000
# 5      0.000000     0.000000    0.000000   0.000000  ...    0.000000
# ..          ...          ...         ...        ...  ...         ...
# 496    0.000000    25.217495    0.000000   0.000000  ...    1.642740
# 497    2.207895     8.081205   33.193836  75.812294  ...    8.006646
# 498  609.379150  1755.137700    0.000000  12.249123  ...    0.000000
# 499    0.000000     0.000000    0.000000   0.000000  ...  146.203870
# 500    0.000000     0.000000    0.000000   0.000000  ...    0.000000
#
#            3178        3179        3180       3181       3182        3183  \
# 1      0.000000    0.000000  299.858920    0.00000    0.00000   63.362545
# 2      0.000000    0.000000    0.000000    0.00000    0.00000    0.000000
# 3    196.810600    0.000000  302.322800  218.80273  165.75368   48.504200
# 4      0.000000    0.000000    0.000000    0.00000    0.00000    0.000000
# 5      0.000000    0.000000    0.000000    0.00000    0.00000    0.000000
# ..          ...         ...         ...        ...        ...         ...
# 496   21.370594    0.000000   70.458650    0.00000    0.00000    0.000000
# 497    9.424434    4.079328   20.738806  163.82272   47.89033   18.380697
# 498    0.000000    0.000000    0.000000    0.00000    0.00000    0.000000
# 499   67.997345  567.739260  278.557460    0.00000  206.99649  137.543090
# 500    0.000000    0.000000    0.000000    0.00000    0.00000    0.000000
#
#            3184       3185        3186
# 1      0.000000   0.000000    1.415787
# 2      0.000000   0.000000    0.000000
# 3    127.762770  80.420840  215.280690
# 4      0.000000   0.000000    0.000000
# 5      0.000000   0.000000    0.000000
# ..          ...        ...         ...
# 496    0.000000   0.000000    0.000000
# 497    2.104182   0.000000    0.000000
# 498    0.000000  27.828867    0.000000
# 499    0.000000  98.665985  651.261960
# 500    0.000000   0.000000    0.000000
#
# [500 rows x 3186 columns]

# %%
# Generate the Heatmap:

plt.figure(figsize=(18,12)) #changes figsize in inches

#use seaborn to create a heatmap (input the modified df, set color bar min/max,
#change color of cmap if needed, and create cbar) 
seaborn.heatmap(new_df, vmin=0, vmax=2000, cmap=None, cbar=True)

#add plot labels:
plt.title('Heatmap of Gene Expression within each cell sample')
plt.xlabel('Cell Sample')
plt.ylabel('Gene')

print(heatMap) #visualize heatmap

fig.savefig('./Heatmap.png', bbox='tight') #save heatmap to file
# Out:
# Figure(720x720)
# C:\Users\benne\AppData\Local\Temp/ipykernel_21808/2207200327.py:16: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.savefig('./Heatmap.png', bbox='tight') #save heatmap to file
